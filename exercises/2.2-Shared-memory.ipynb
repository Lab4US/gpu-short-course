# %%
# import math
# import numpy as np
# from numba import cuda, float32

# thread_block_size_deafult = 256

# %%
# @cuda.jit
# def convolve_kernel(y, x, h):
#     i = cuda.blockIdx.x*cuda.blockDim.x + cuda.threadIdx.x
    
#     if i >= y.shape[0]:
#         return
    
#     filter_size = len(h)
#     x_sm = cuda.shared.array(shape=0, dtype=float32)
#     sm_size = cuda.blockDim.x+filter_size-1
    
#     # Copy a portion global memory data to shared memory.
#     k = i - (filter_size-1) # The current position in the global memory.
#     k_sm = cuda.threadIdx.x # The current position in the shared memory.  
#     while k_sm < sm_size:
#         if k < 0:
#             x_sm[k_sm] = 0.0
#         else:
#             x_sm[k_sm] = x[k]
#         k_sm += cuda.blockDim.x
#         k    += cuda.blockDim.x

#     cuda.syncthreads()
    
#     k_sm = cuda.threadIdx.x+filter_size-1
#     value = 0.0
#     for j in range(filter_size):
#         value += x_sm[k_sm-j]*h[j]
#     y[i] = value

    
# def convolve(y, x, h):
#     thread_block_size = min(thread_block_size_deafult, len(y))
#     block_size = (thread_block_size, )
#     grid_size = (math.ceil(len(y)/block_size[0]), )
#     filter_size = len(h)
#     shared_memory_size = thread_block_size+filter_size-1
#     shared_memory_size_bytes = shared_memory_size * y.dtype.itemsize
#     convolve_kernel[grid_size, block_size, 0, shared_memory_size_bytes](y, x, h)  
    
    
# x = np.array([0, 1, 2, 3, 4])
# h = np.array([0, 1, 2])
# y_gpu = cuda.device_array(len(x))

# convolve(y_gpu, x, h)

# y_host = y_gpu.copy_to_host()
# np.testing.assert_equal(y_host, [0, 0, 1, 4, 7])
# y_host

# %%
# %%writefile 2.2-convolve-1d-shared-memory.py

import math
import numpy as np
from numba import cuda, float32

thread_block_size_deafult = 256


@cuda.jit
def convolve_kernel(y, x, h):
    i = cuda.blockIdx.x*cuda.blockDim.x + cuda.threadIdx.x
    
    if i >= y.shape[0]:
        return
    
    filter_size = len(h)
    x_sm = cuda.shared.array(shape=0, dtype=float32)
    sm_size = cuda.blockDim.x+filter_size-1
    
    # Copy a portion global memory data to shared memory.
    k = i - (filter_size-1) # The current position in the global memory.
    k_sm = cuda.threadIdx.x # The current position in the shared memory.  
    while k_sm < sm_size:
        if k < 0:
            x_sm[k_sm] = float32(0.0)
        else:
            x_sm[k_sm] = x[k]
        k_sm += cuda.blockDim.x
        k    += cuda.blockDim.x

    cuda.syncthreads()
    
    k_sm = cuda.threadIdx.x+filter_size-1
    value = float32(0.0)
    for j in range(filter_size):
        value += x_sm[k_sm-j]*h[j]
    y[i] = value

    
def convolve(y, x, h):
    thread_block_size = min(thread_block_size_deafult, len(y))
    block_size = (thread_block_size, )
    grid_size = (math.ceil(len(y)/block_size[0]), )
    filter_size = len(h)
    shared_memory_size = thread_block_size+filter_size-1
    shared_memory_size_bytes = shared_memory_size*y.dtype.itemsize
    convolve_kernel[grid_size, block_size, cuda.default_stream(), shared_memory_size_bytes](y, x, h)  
    
# Test data.
n = 1024*64*16*16

for i in range(20):
    x_host = np.random.rand(n).astype(np.float32)
    h_host = np.random.rand(256).astype(np.float32)
    y_gpu = cuda.device_array(shape=(n,), dtype=np.float32)
    x_gpu = cuda.to_device(x_host)
    h_gpu = cuda.to_device(h_host)
    convolve(y_gpu, x_gpu, h_gpu)
    y_host = y_gpu.copy_to_host()
# Out:
# Overwriting 2.2-convolve-1d-shared-memory.py

# %%
! nsys profile --stats=true -t cuda python 2.2-convolve-1d-shared-memory.py
# Out:
# Warning: LBR backtrace method is not supported on this platform. DWARF backtrace method will be used.
# Collecting data...
# Processing events...
# Saving temporary "/tmp/nsys-report-7ebb-93a4-c60e-749d.qdstrm" file to disk...
# Creating final output files...
#
# Processing [==============================================================100%]
# Saved report file to "/tmp/nsys-report-7ebb-93a4-c60e-749d.qdrep"
# Exporting 334 events: [===================================================100%]
#
# Exported successfully to
# /tmp/nsys-report-7ebb-93a4-c60e-749d.sqlite
#
# Generating CUDA API Statistics...
# CUDA API Statistics (nanoseconds)
#
# Time(%)      Total Time       Calls         Average         Minimum         Maximum  Name
# -------  --------------  ----------  --------------  --------------  --------------  --------------------------------------------------------------------------------
#    80.2       733124781          20      36656239.0        35987419        38240690  cuMemcpyDtoH_v2
#    14.6       133835705          40       3345892.6            7751        13451342  cuMemcpyHtoD_v2
#     4.0        36861484          55        670208.8            2811         2106144  cuMemFree_v2
#     1.0         9270409          60        154506.8            4986         1951641  cuMemAlloc_v2
#     0.0          338566          20         16928.3           16189           17875  cuLaunchKernel
#     0.0          232919           1        232919.0          232919          232919  cuModuleLoadDataEx
#     0.0           83293           1         83293.0           83293           83293  cuLinkComplete
#     0.0           32035           1         32035.0           32035           32035  cuLinkCreate_v2
#     0.0           18443           1         18443.0           18443           18443  cuMemGetInfo_v2
#     0.0            1286           1          1286.0            1286            1286  cuInit
#     0.0            1131           1          1131.0            1131            1131  cuLinkDestroy
#
#
#
#
# Generating CUDA Kernel Statistics...
# CUDA Kernel Statistics (nanoseconds)
#
# Time(%)      Total Time   Instances         Average         Minimum         Maximum  Name
# -------  --------------  ----------  --------------  --------------  --------------  --------------------------------------------------------------------------------------------------------------------
#   100.0       516070719          20      25803535.9        25790500        25813797  cudapy::__main__::convolve_kernel$241(Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>)
#
#
#
# Generating CUDA Memory Operation Statistics...
# CUDA Memory Operation Statistics (nanoseconds)
#
# Time(%)      Total Time  Operations         Average         Minimum         Maximum  Name
# -------  --------------  ----------  --------------  --------------  --------------  --------------------------------------------------------------------------------
#    61.8       214166327          20      10708316.3        10022135        12368890  [CUDA memcpy DtoH]
#    38.2       132156068          40       3303901.7            1247        12697983  [CUDA memcpy HtoD]
#
#
# CUDA Memory Operation Statistics (KiB)
#
#               Total      Operations              Average            Minimum              Maximum  Name
# -------------------  --------------  -------------------  -----------------  -------------------  --------------------------------------------------------------------------------
#         1310740.000              40            32768.500              1.000            65536.000  [CUDA memcpy HtoD]
#         1310720.000              20            65536.000          65536.000            65536.000  [CUDA memcpy DtoH]
#
#
#
# Report file moved to "/rapids/notebooks/src/ius-2021-gpu-short-course/exercises/report2.qdrep"
# Report file moved to "/rapids/notebooks/src/ius-2021-gpu-short-course/exercises/report2.sqlite"

# %%
! ncu --section MemoryWorkloadAnalysis python 2.2-convolve-1d-shared-memory.py
# Out:
# ==PROF== Connected to process 13207 (/opt/conda/envs/rapids/bin/python3.7)
# ==PROF== Profiling "convolve_kernel$241" - 1: 0%....50%....100% - 7 passes
# ==PROF== Profiling "convolve_kernel$241" - 2: 0%....50%....100% - 7 passes
# ==PROF== Profiling "convolve_kernel$241" - 3: 0%....50%....100% - 7 passes
# ==PROF== Profiling "convolve_kernel$241" - 4: 0%....50%....100% - 7 passes
# ==PROF== Profiling "convolve_kernel$241" - 5: 0%....50%....100% - 7 passes
# ==PROF== Profiling "convolve_kernel$241" - 6: 0%....50%....100% - 7 passes
# ==PROF== Profiling "convolve_kernel$241" - 7: 0%....50%....100% - 7 passes
# ==PROF== Profiling "convolve_kernel$241" - 8: 0%....50%....100% - 7 passes
# ==PROF== Profiling "convolve_kernel$241" - 9: 0%....50%....100% - 7 passes
# ==PROF== Profiling "convolve_kernel$241" - 10: 0%....50%....100% - 7 passes
# ==PROF== Profiling "convolve_kernel$241" - 11: 0%....50%....100% - 7 passes
# ==PROF== Profiling "convolve_kernel$241" - 12: 0%....50%....100% - 7 passes
# ==PROF== Profiling "convolve_kernel$241" - 13: 0%....50%....100% - 7 passes
# ==PROF== Profiling "convolve_kernel$241" - 14: 0%....50%....100% - 7 passes
# ==PROF== Profiling "convolve_kernel$241" - 15: 0%....50%....100% - 7 passes
# ==PROF== Profiling "convolve_kernel$241" - 16: 0%....50%....100% - 7 passes
# ==PROF== Profiling "convolve_kernel$241" - 17: 0%....50%....100% - 7 passes
# ==PROF== Profiling "convolve_kernel$241" - 18: 0%....50%....100% - 7 passes
# ==PROF== Profiling "convolve_kernel$241" - 19: 0%....50%....100% - 7 passes
# ==PROF== Profiling "convolve_kernel$241" - 20: 0%....50%....100% - 7 passes
# ==PROF== Disconnected from process 13207
# [13207] python3.7@127.0.0.1
#   cudapy::__main__::convolve_kernel$241(Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>), 2021-Jun-20 16:02:16, Context 1, Stream 7
#     Section: Memory Workload Analysis
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     Memory Throughput                                                         Gbyte/second                           3.84
#     Mem Busy                                                                             %                          20.50
#     Max Bandwidth                                                                        %                          40.86
#     L1/TEX Hit Rate                                                                      %                          95.64
#     L2 Compression Success Rate                                                          %                              0
#     L2 Compression Ratio                                                                                                0
#     L2 Hit Rate                                                                          %                          56.14
#     Mem Pipes Busy                                                                       %                          40.86
#     ---------------------------------------------------------------------- --------------- ------------------------------
#
#   cudapy::__main__::convolve_kernel$241(Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>), 2021-Jun-20 16:02:17, Context 1, Stream 7
#     Section: Memory Workload Analysis
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     Memory Throughput                                                         Gbyte/second                           3.53
#     Mem Busy                                                                             %                          20.50
#     Max Bandwidth                                                                        %                          40.86
#     L1/TEX Hit Rate                                                                      %                          95.64
#     L2 Compression Success Rate                                                          %                              0
#     L2 Compression Ratio                                                                                                0
#     L2 Hit Rate                                                                          %                          60.97
#     Mem Pipes Busy                                                                       %                          40.86
#     ---------------------------------------------------------------------- --------------- ------------------------------
#
#   cudapy::__main__::convolve_kernel$241(Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>), 2021-Jun-20 16:02:18, Context 1, Stream 7
#     Section: Memory Workload Analysis
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     Memory Throughput                                                         Gbyte/second                           3.74
#     Mem Busy                                                                             %                          20.50
#     Max Bandwidth                                                                        %                          40.86
#     L1/TEX Hit Rate                                                                      %                          95.64
#     L2 Compression Success Rate                                                          %                              0
#     L2 Compression Ratio                                                                                                0
#     L2 Hit Rate                                                                          %                          58.20
#     Mem Pipes Busy                                                                       %                          40.86
#     ---------------------------------------------------------------------- --------------- ------------------------------
#
#   cudapy::__main__::convolve_kernel$241(Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>), 2021-Jun-20 16:02:18, Context 1, Stream 7
#     Section: Memory Workload Analysis
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     Memory Throughput                                                         Gbyte/second                           3.56
#     Mem Busy                                                                             %                          20.50
#     Max Bandwidth                                                                        %                          40.86
#     L1/TEX Hit Rate                                                                      %                          95.64
#     L2 Compression Success Rate                                                          %                              0
#     L2 Compression Ratio                                                                                                0
#     L2 Hit Rate                                                                          %                          61.08
#     Mem Pipes Busy                                                                       %                          40.86
#     ---------------------------------------------------------------------- --------------- ------------------------------
#
#   cudapy::__main__::convolve_kernel$241(Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>), 2021-Jun-20 16:02:19, Context 1, Stream 7
#     Section: Memory Workload Analysis
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     Memory Throughput                                                         Gbyte/second                           3.73
#     Mem Busy                                                                             %                          20.50
#     Max Bandwidth                                                                        %                          40.86
#     L1/TEX Hit Rate                                                                      %                          95.64
#     L2 Compression Success Rate                                                          %                              0
#     L2 Compression Ratio                                                                                                0
#     L2 Hit Rate                                                                          %                          58.52
#     Mem Pipes Busy                                                                       %                          40.86
#     ---------------------------------------------------------------------- --------------- ------------------------------
#
#   cudapy::__main__::convolve_kernel$241(Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>), 2021-Jun-20 16:02:19, Context 1, Stream 7
#     Section: Memory Workload Analysis
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     Memory Throughput                                                         Gbyte/second                           3.76
#     Mem Busy                                                                             %                          20.50
#     Max Bandwidth                                                                        %                          40.86
#     L1/TEX Hit Rate                                                                      %                          95.64
#     L2 Compression Success Rate                                                          %                              0
#     L2 Compression Ratio                                                                                                0
#     L2 Hit Rate                                                                          %                          57.14
#     Mem Pipes Busy                                                                       %                          40.86
#     ---------------------------------------------------------------------- --------------- ------------------------------
#
#   cudapy::__main__::convolve_kernel$241(Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>), 2021-Jun-20 16:02:20, Context 1, Stream 7
#     Section: Memory Workload Analysis
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     Memory Throughput                                                         Gbyte/second                           3.56
#     Mem Busy                                                                             %                          20.50
#     Max Bandwidth                                                                        %                          40.86
#     L1/TEX Hit Rate                                                                      %                          95.64
#     L2 Compression Success Rate                                                          %                              0
#     L2 Compression Ratio                                                                                                0
#     L2 Hit Rate                                                                          %                          59.37
#     Mem Pipes Busy                                                                       %                          40.86
#     ---------------------------------------------------------------------- --------------- ------------------------------
#
#   cudapy::__main__::convolve_kernel$241(Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>), 2021-Jun-20 16:02:20, Context 1, Stream 7
#     Section: Memory Workload Analysis
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     Memory Throughput                                                         Gbyte/second                           3.74
#     Mem Busy                                                                             %                          20.50
#     Max Bandwidth                                                                        %                          40.86
#     L1/TEX Hit Rate                                                                      %                          95.64
#     L2 Compression Success Rate                                                          %                              0
#     L2 Compression Ratio                                                                                                0
#     L2 Hit Rate                                                                          %                          60.19
#     Mem Pipes Busy                                                                       %                          40.86
#     ---------------------------------------------------------------------- --------------- ------------------------------
#
#   cudapy::__main__::convolve_kernel$241(Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>), 2021-Jun-20 16:02:21, Context 1, Stream 7
#     Section: Memory Workload Analysis
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     Memory Throughput                                                         Gbyte/second                           3.73
#     Mem Busy                                                                             %                          20.50
#     Max Bandwidth                                                                        %                          40.86
#     L1/TEX Hit Rate                                                                      %                          95.65
#     L2 Compression Success Rate                                                          %                              0
#     L2 Compression Ratio                                                                                                0
#     L2 Hit Rate                                                                          %                          58.31
#     Mem Pipes Busy                                                                       %                          40.86
#     ---------------------------------------------------------------------- --------------- ------------------------------
#
#   cudapy::__main__::convolve_kernel$241(Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>), 2021-Jun-20 16:02:22, Context 1, Stream 7
#     Section: Memory Workload Analysis
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     Memory Throughput                                                         Gbyte/second                           3.76
#     Mem Busy                                                                             %                          20.50
#     Max Bandwidth                                                                        %                          40.86
#     L1/TEX Hit Rate                                                                      %                          95.64
#     L2 Compression Success Rate                                                          %                              0
#     L2 Compression Ratio                                                                                                0
#     L2 Hit Rate                                                                          %                          57.29
#     Mem Pipes Busy                                                                       %                          40.86
#     ---------------------------------------------------------------------- --------------- ------------------------------
#
#   cudapy::__main__::convolve_kernel$241(Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>), 2021-Jun-20 16:02:22, Context 1, Stream 7
#     Section: Memory Workload Analysis
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     Memory Throughput                                                         Gbyte/second                           3.53
#     Mem Busy                                                                             %                          20.50
#     Max Bandwidth                                                                        %                          40.86
#     L1/TEX Hit Rate                                                                      %                          95.64
#     L2 Compression Success Rate                                                          %                              0
#     L2 Compression Ratio                                                                                                0
#     L2 Hit Rate                                                                          %                          62.86
#     Mem Pipes Busy                                                                       %                          40.86
#     ---------------------------------------------------------------------- --------------- ------------------------------
#
#   cudapy::__main__::convolve_kernel$241(Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>), 2021-Jun-20 16:02:23, Context 1, Stream 7
#     Section: Memory Workload Analysis
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     Memory Throughput                                                         Gbyte/second                           3.73
#     Mem Busy                                                                             %                          20.50
#     Max Bandwidth                                                                        %                          40.86
#     L1/TEX Hit Rate                                                                      %                          95.64
#     L2 Compression Success Rate                                                          %                              0
#     L2 Compression Ratio                                                                                                0
#     L2 Hit Rate                                                                          %                          58.71
#     Mem Pipes Busy                                                                       %                          40.86
#     ---------------------------------------------------------------------- --------------- ------------------------------
#
#   cudapy::__main__::convolve_kernel$241(Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>), 2021-Jun-20 16:02:23, Context 1, Stream 7
#     Section: Memory Workload Analysis
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     Memory Throughput                                                         Gbyte/second                           3.73
#     Mem Busy                                                                             %                          20.50
#     Max Bandwidth                                                                        %                          40.86
#     L1/TEX Hit Rate                                                                      %                          95.64
#     L2 Compression Success Rate                                                          %                              0
#     L2 Compression Ratio                                                                                                0
#     L2 Hit Rate                                                                          %                          58.57
#     Mem Pipes Busy                                                                       %                          40.86
#     ---------------------------------------------------------------------- --------------- ------------------------------
#
#   cudapy::__main__::convolve_kernel$241(Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>), 2021-Jun-20 16:02:24, Context 1, Stream 7
#     Section: Memory Workload Analysis
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     Memory Throughput                                                         Gbyte/second                           3.56
#     Mem Busy                                                                             %                          20.50
#     Max Bandwidth                                                                        %                          40.86
#     L1/TEX Hit Rate                                                                      %                          95.64
#     L2 Compression Success Rate                                                          %                              0
#     L2 Compression Ratio                                                                                                0
#     L2 Hit Rate                                                                          %                          60.32
#     Mem Pipes Busy                                                                       %                          40.86
#     ---------------------------------------------------------------------- --------------- ------------------------------
#
#   cudapy::__main__::convolve_kernel$241(Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>), 2021-Jun-20 16:02:25, Context 1, Stream 7
#     Section: Memory Workload Analysis
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     Memory Throughput                                                         Gbyte/second                           3.73
#     Mem Busy                                                                             %                          20.50
#     Max Bandwidth                                                                        %                          40.86
#     L1/TEX Hit Rate                                                                      %                          95.64
#     L2 Compression Success Rate                                                          %                              0
#     L2 Compression Ratio                                                                                                0
#     L2 Hit Rate                                                                          %                          60.30
#     Mem Pipes Busy                                                                       %                          40.86
#     ---------------------------------------------------------------------- --------------- ------------------------------
#
#   cudapy::__main__::convolve_kernel$241(Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>), 2021-Jun-20 16:02:25, Context 1, Stream 7
#     Section: Memory Workload Analysis
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     Memory Throughput                                                         Gbyte/second                           3.53
#     Mem Busy                                                                             %                          20.50
#     Max Bandwidth                                                                        %                          40.86
#     L1/TEX Hit Rate                                                                      %                          95.64
#     L2 Compression Success Rate                                                          %                              0
#     L2 Compression Ratio                                                                                                0
#     L2 Hit Rate                                                                          %                          60.68
#     Mem Pipes Busy                                                                       %                          40.86
#     ---------------------------------------------------------------------- --------------- ------------------------------
#
#   cudapy::__main__::convolve_kernel$241(Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>), 2021-Jun-20 16:02:26, Context 1, Stream 7
#     Section: Memory Workload Analysis
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     Memory Throughput                                                         Gbyte/second                           3.74
#     Mem Busy                                                                             %                          20.50
#     Max Bandwidth                                                                        %                          40.86
#     L1/TEX Hit Rate                                                                      %                          95.64
#     L2 Compression Success Rate                                                          %                              0
#     L2 Compression Ratio                                                                                                0
#     L2 Hit Rate                                                                          %                          59.81
#     Mem Pipes Busy                                                                       %                          40.86
#     ---------------------------------------------------------------------- --------------- ------------------------------
#
#   cudapy::__main__::convolve_kernel$241(Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>), 2021-Jun-20 16:02:26, Context 1, Stream 7
#     Section: Memory Workload Analysis
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     Memory Throughput                                                         Gbyte/second                           3.53
#     Mem Busy                                                                             %                          20.50
#     Max Bandwidth                                                                        %                          40.86
#     L1/TEX Hit Rate                                                                      %                          95.64
#     L2 Compression Success Rate                                                          %                              0
#     L2 Compression Ratio                                                                                                0
#     L2 Hit Rate                                                                          %                          63.73
#     Mem Pipes Busy                                                                       %                          40.86
#     ---------------------------------------------------------------------- --------------- ------------------------------
#
#   cudapy::__main__::convolve_kernel$241(Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>), 2021-Jun-20 16:02:27, Context 1, Stream 7
#     Section: Memory Workload Analysis
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     Memory Throughput                                                         Gbyte/second                           3.73
#     Mem Busy                                                                             %                          20.50
#     Max Bandwidth                                                                        %                          40.86
#     L1/TEX Hit Rate                                                                      %                          95.64
#     L2 Compression Success Rate                                                          %                              0
#     L2 Compression Ratio                                                                                                0
#     L2 Hit Rate                                                                          %                          58.45
#     Mem Pipes Busy                                                                       %                          40.86
#     ---------------------------------------------------------------------- --------------- ------------------------------
#
#   cudapy::__main__::convolve_kernel$241(Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>), 2021-Jun-20 16:02:27, Context 1, Stream 7
#     Section: Memory Workload Analysis
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     Memory Throughput                                                         Gbyte/second                           3.76
#     Mem Busy                                                                             %                          20.50
#     Max Bandwidth                                                                        %                          40.86
#     L1/TEX Hit Rate                                                                      %                          95.64
#     L2 Compression Success Rate                                                          %                              0
#     L2 Compression Ratio                                                                                                0
#     L2 Hit Rate                                                                          %                          57.93
#     Mem Pipes Busy                                                                       %                          40.86
#     ---------------------------------------------------------------------- --------------- ------------------------------

# %%
# ! nsys profile --stats=true -t cuda python 2.2-convolve-1d-shared-memory.py
! ncu python 2.2-convolve-1d-shared-memory.py
# Out:
# ==PROF== Connected to process 13231 (/opt/conda/envs/rapids/bin/python3.7)
# ==PROF== Profiling "convolve_kernel$241" - 1: 0%....50%....100% - 8 passes
# ==PROF== Profiling "convolve_kernel$241" - 2: 0%....50%....100% - 8 passes
# ==PROF== Profiling "convolve_kernel$241" - 3: 0%....50%....100% - 8 passes
# ==PROF== Profiling "convolve_kernel$241" - 4: 0%....50%....100% - 8 passes
# ==PROF== Profiling "convolve_kernel$241" - 5: 0%....50%....100% - 8 passes
# ==PROF== Profiling "convolve_kernel$241" - 6: 0%....50%....100% - 8 passes
# ==PROF== Profiling "convolve_kernel$241" - 7: 0%....50%....100% - 8 passes
# ==PROF== Profiling "convolve_kernel$241" - 8: 0%....50%....100% - 8 passes
# ==PROF== Profiling "convolve_kernel$241" - 9: 0%....50%....100% - 8 passes
# ==PROF== Profiling "convolve_kernel$241" - 10: 0%....50%....100% - 8 passes
# ==PROF== Profiling "convolve_kernel$241" - 11: 0%....50%....100% - 8 passes
# ==PROF== Profiling "convolve_kernel$241" - 12: 0%....50%....100% - 8 passes
# ==PROF== Profiling "convolve_kernel$241" - 13: 0%....50%....100% - 8 passes
# ==PROF== Profiling "convolve_kernel$241" - 14: 0%....50%....100% - 8 passes
# ==PROF== Profiling "convolve_kernel$241" - 15: 0%....50%....100% - 8 passes
# ==PROF== Profiling "convolve_kernel$241" - 16: 0%....50%....100% - 8 passes
# ==PROF== Profiling "convolve_kernel$241" - 17: 0%....50%....100% - 8 passes
# ==PROF== Profiling "convolve_kernel$241" - 18: 0%....50%....100% - 8 passes
# ==PROF== Profiling "convolve_kernel$241" - 19: 0%....50%....100% - 8 passes
# ==PROF== Profiling "convolve_kernel$241" - 20: 0%....50%....100% - 8 passes
# ==PROF== Disconnected from process 13231
# [13231] python3.7@127.0.0.1
#   cudapy::__main__::convolve_kernel$241(Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>), 2021-Jun-20 16:02:30, Context 1, Stream 7
#     Section: GPU Speed Of Light
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     DRAM Frequency                                                           cycle/nsecond                           6.00
#     SM Frequency                                                             cycle/usecond                         780.00
#     Elapsed Cycles                                                                   cycle                     33,235,016
#     Memory [%]                                                                           %                          40.86
#     SOL DRAM                                                                             %                           0.97
#     Duration                                                                       msecond                          42.61
#     SOL L1/TEX Cache                                                                     %                          40.87
#     SOL L2 Cache                                                                         %                           0.66
#     SM Active Cycles                                                                 cycle                  33,220,996.93
#     SM [%]                                                                               %                          91.75
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     OK    The kernel is utilizing greater than 80.0% of the available compute or memory performance of the device. To
#           further improve performance, work will likely need to be shifted from the most utilized to another unit.
#           Start by analyzing workloads in the Compute Workload Analysis section.
#
#     Section: Launch Statistics
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     Block Size                                                                                                        256
#     Function Cache Configuration                                                                  cudaFuncCachePreferNone
#     Grid Size                                                                                                      65,536
#     Registers Per Thread                                                   register/thread                             20
#     Shared Memory Configuration Size                                                 Kbyte                          32.77
#     Driver Shared Memory Per Block                                             Kbyte/block                           1.02
#     Dynamic Shared Memory Per Block                                            Kbyte/block                           2.04
#     Static Shared Memory Per Block                                              byte/block                              0
#     Threads                                                                         thread                     16,777,216
#     Waves Per SM                                                                                                   273.07
#     ---------------------------------------------------------------------- --------------- ------------------------------
#
#     Section: Occupancy
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     Block Limit SM                                                                   block                             16
#     Block Limit Registers                                                            block                             10
#     Block Limit Shared Mem                                                           block                             33
#     Block Limit Warps                                                                block                              6
#     Theoretical Active Warps per SM                                                   warp                             48
#     Theoretical Occupancy                                                                %                            100
#     Achieved Occupancy                                                                   %                          99.41
#     Achieved Active Warps Per SM                                                      warp                          47.72
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     OK    This kernel's theoretical occupancy is not impacted by any block limit.
#
#   cudapy::__main__::convolve_kernel$241(Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>), 2021-Jun-20 16:02:30, Context 1, Stream 7
#     Section: GPU Speed Of Light
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     DRAM Frequency                                                           cycle/nsecond                           6.00
#     SM Frequency                                                             cycle/usecond                         780.00
#     Elapsed Cycles                                                                   cycle                     33,234,991
#     Memory [%]                                                                           %                          40.86
#     SOL DRAM                                                                             %                           0.95
#     Duration                                                                       msecond                          42.61
#     SOL L1/TEX Cache                                                                     %                          40.88
#     SOL L2 Cache                                                                         %                           0.66
#     SM Active Cycles                                                                 cycle                  33,220,937.12
#     SM [%]                                                                               %                          91.75
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     OK    The kernel is utilizing greater than 80.0% of the available compute or memory performance of the device. To
#           further improve performance, work will likely need to be shifted from the most utilized to another unit.
#           Start by analyzing workloads in the Compute Workload Analysis section.
#
#     Section: Launch Statistics
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     Block Size                                                                                                        256
#     Function Cache Configuration                                                                  cudaFuncCachePreferNone
#     Grid Size                                                                                                      65,536
#     Registers Per Thread                                                   register/thread                             20
#     Shared Memory Configuration Size                                                 Kbyte                          32.77
#     Driver Shared Memory Per Block                                             Kbyte/block                           1.02
#     Dynamic Shared Memory Per Block                                            Kbyte/block                           2.04
#     Static Shared Memory Per Block                                              byte/block                              0
#     Threads                                                                         thread                     16,777,216
#     Waves Per SM                                                                                                   273.07
#     ---------------------------------------------------------------------- --------------- ------------------------------
#
#     Section: Occupancy
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     Block Limit SM                                                                   block                             16
#     Block Limit Registers                                                            block                             10
#     Block Limit Shared Mem                                                           block                             33
#     Block Limit Warps                                                                block                              6
#     Theoretical Active Warps per SM                                                   warp                             48
#     Theoretical Occupancy                                                                %                            100
#     Achieved Occupancy                                                                   %                          99.41
#     Achieved Active Warps Per SM                                                      warp                          47.72
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     OK    This kernel's theoretical occupancy is not impacted by any block limit.
#
#   cudapy::__main__::convolve_kernel$241(Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>), 2021-Jun-20 16:02:31, Context 1, Stream 7
#     Section: GPU Speed Of Light
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     DRAM Frequency                                                           cycle/nsecond                           6.00
#     SM Frequency                                                             cycle/usecond                         780.00
#     Elapsed Cycles                                                                   cycle                     33,235,403
#     Memory [%]                                                                           %                          40.86
#     SOL DRAM                                                                             %                           0.92
#     Duration                                                                       msecond                          42.61
#     SOL L1/TEX Cache                                                                     %                          40.87
#     SOL L2 Cache                                                                         %                           0.63
#     SM Active Cycles                                                                 cycle                  33,221,028.75
#     SM [%]                                                                               %                          91.75
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     OK    The kernel is utilizing greater than 80.0% of the available compute or memory performance of the device. To
#           further improve performance, work will likely need to be shifted from the most utilized to another unit.
#           Start by analyzing workloads in the Compute Workload Analysis section.
#
#     Section: Launch Statistics
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     Block Size                                                                                                        256
#     Function Cache Configuration                                                                  cudaFuncCachePreferNone
#     Grid Size                                                                                                      65,536
#     Registers Per Thread                                                   register/thread                             20
#     Shared Memory Configuration Size                                                 Kbyte                          32.77
#     Driver Shared Memory Per Block                                             Kbyte/block                           1.02
#     Dynamic Shared Memory Per Block                                            Kbyte/block                           2.04
#     Static Shared Memory Per Block                                              byte/block                              0
#     Threads                                                                         thread                     16,777,216
#     Waves Per SM                                                                                                   273.07
#     ---------------------------------------------------------------------- --------------- ------------------------------
#
#     Section: Occupancy
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     Block Limit SM                                                                   block                             16
#     Block Limit Registers                                                            block                             10
#     Block Limit Shared Mem                                                           block                             33
#     Block Limit Warps                                                                block                              6
#     Theoretical Active Warps per SM                                                   warp                             48
#     Theoretical Occupancy                                                                %                            100
#     Achieved Occupancy                                                                   %                          99.41
#     Achieved Active Warps Per SM                                                      warp                          47.72
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     OK    This kernel's theoretical occupancy is not impacted by any block limit.
#
#   cudapy::__main__::convolve_kernel$241(Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>), 2021-Jun-20 16:02:32, Context 1, Stream 7
#     Section: GPU Speed Of Light
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     DRAM Frequency                                                           cycle/nsecond                           6.00
#     SM Frequency                                                             cycle/usecond                         780.00
#     Elapsed Cycles                                                                   cycle                     33,235,232
#     Memory [%]                                                                           %                          40.86
#     SOL DRAM                                                                             %                           0.92
#     Duration                                                                       msecond                          42.61
#     SOL L1/TEX Cache                                                                     %                          40.87
#     SOL L2 Cache                                                                         %                           0.64
#     SM Active Cycles                                                                 cycle                  33,221,188.93
#     SM [%]                                                                               %                          91.75
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     OK    The kernel is utilizing greater than 80.0% of the available compute or memory performance of the device. To
#           further improve performance, work will likely need to be shifted from the most utilized to another unit.
#           Start by analyzing workloads in the Compute Workload Analysis section.
#
#     Section: Launch Statistics
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     Block Size                                                                                                        256
#     Function Cache Configuration                                                                  cudaFuncCachePreferNone
#     Grid Size                                                                                                      65,536
#     Registers Per Thread                                                   register/thread                             20
#     Shared Memory Configuration Size                                                 Kbyte                          32.77
#     Driver Shared Memory Per Block                                             Kbyte/block                           1.02
#     Dynamic Shared Memory Per Block                                            Kbyte/block                           2.04
#     Static Shared Memory Per Block                                              byte/block                              0
#     Threads                                                                         thread                     16,777,216
#     Waves Per SM                                                                                                   273.07
#     ---------------------------------------------------------------------- --------------- ------------------------------
#
#     Section: Occupancy
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     Block Limit SM                                                                   block                             16
#     Block Limit Registers                                                            block                             10
#     Block Limit Shared Mem                                                           block                             33
#     Block Limit Warps                                                                block                              6
#     Theoretical Active Warps per SM                                                   warp                             48
#     Theoretical Occupancy                                                                %                            100
#     Achieved Occupancy                                                                   %                          99.41
#     Achieved Active Warps Per SM                                                      warp                          47.72
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     OK    This kernel's theoretical occupancy is not impacted by any block limit.
#
#   cudapy::__main__::convolve_kernel$241(Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>), 2021-Jun-20 16:02:32, Context 1, Stream 7
#     Section: GPU Speed Of Light
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     DRAM Frequency                                                           cycle/nsecond                           5.99
#     SM Frequency                                                             cycle/usecond                         779.99
#     Elapsed Cycles                                                                   cycle                     33,234,885
#     Memory [%]                                                                           %                          40.86
#     SOL DRAM                                                                             %                           0.97
#     Duration                                                                       msecond                          42.61
#     SOL L1/TEX Cache                                                                     %                          40.88
#     SOL L2 Cache                                                                         %                           0.66
#     SM Active Cycles                                                                 cycle                  33,220,712.73
#     SM [%]                                                                               %                          91.75
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     OK    The kernel is utilizing greater than 80.0% of the available compute or memory performance of the device. To
#           further improve performance, work will likely need to be shifted from the most utilized to another unit.
#           Start by analyzing workloads in the Compute Workload Analysis section.
#
#     Section: Launch Statistics
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     Block Size                                                                                                        256
#     Function Cache Configuration                                                                  cudaFuncCachePreferNone
#     Grid Size                                                                                                      65,536
#     Registers Per Thread                                                   register/thread                             20
#     Shared Memory Configuration Size                                                 Kbyte                          32.77
#     Driver Shared Memory Per Block                                             Kbyte/block                           1.02
#     Dynamic Shared Memory Per Block                                            Kbyte/block                           2.04
#     Static Shared Memory Per Block                                              byte/block                              0
#     Threads                                                                         thread                     16,777,216
#     Waves Per SM                                                                                                   273.07
#     ---------------------------------------------------------------------- --------------- ------------------------------
#
#     Section: Occupancy
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     Block Limit SM                                                                   block                             16
#     Block Limit Registers                                                            block                             10
#     Block Limit Shared Mem                                                           block                             33
#     Block Limit Warps                                                                block                              6
#     Theoretical Active Warps per SM                                                   warp                             48
#     Theoretical Occupancy                                                                %                            100
#     Achieved Occupancy                                                                   %                          99.41
#     Achieved Active Warps Per SM                                                      warp                          47.72
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     OK    This kernel's theoretical occupancy is not impacted by any block limit.
#
#   cudapy::__main__::convolve_kernel$241(Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>), 2021-Jun-20 16:02:33, Context 1, Stream 7
#     Section: GPU Speed Of Light
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     DRAM Frequency                                                           cycle/nsecond                           5.99
#     SM Frequency                                                             cycle/usecond                         779.99
#     Elapsed Cycles                                                                   cycle                     33,234,713
#     Memory [%]                                                                           %                          40.86
#     SOL DRAM                                                                             %                           0.93
#     Duration                                                                       msecond                          42.61
#     SOL L1/TEX Cache                                                                     %                          40.88
#     SOL L2 Cache                                                                         %                           0.65
#     SM Active Cycles                                                                 cycle                     33,220,706
#     SM [%]                                                                               %                          91.75
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     OK    The kernel is utilizing greater than 80.0% of the available compute or memory performance of the device. To
#           further improve performance, work will likely need to be shifted from the most utilized to another unit.
#           Start by analyzing workloads in the Compute Workload Analysis section.
#
#     Section: Launch Statistics
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     Block Size                                                                                                        256
#     Function Cache Configuration                                                                  cudaFuncCachePreferNone
#     Grid Size                                                                                                      65,536
#     Registers Per Thread                                                   register/thread                             20
#     Shared Memory Configuration Size                                                 Kbyte                          32.77
#     Driver Shared Memory Per Block                                             Kbyte/block                           1.02
#     Dynamic Shared Memory Per Block                                            Kbyte/block                           2.04
#     Static Shared Memory Per Block                                              byte/block                              0
#     Threads                                                                         thread                     16,777,216
#     Waves Per SM                                                                                                   273.07
#     ---------------------------------------------------------------------- --------------- ------------------------------
#
#     Section: Occupancy
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     Block Limit SM                                                                   block                             16
#     Block Limit Registers                                                            block                             10
#     Block Limit Shared Mem                                                           block                             33
#     Block Limit Warps                                                                block                              6
#     Theoretical Active Warps per SM                                                   warp                             48
#     Theoretical Occupancy                                                                %                            100
#     Achieved Occupancy                                                                   %                          99.41
#     Achieved Active Warps Per SM                                                      warp                          47.72
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     OK    This kernel's theoretical occupancy is not impacted by any block limit.
#
#   cudapy::__main__::convolve_kernel$241(Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>), 2021-Jun-20 16:02:34, Context 1, Stream 7
#     Section: GPU Speed Of Light
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     DRAM Frequency                                                           cycle/nsecond                           6.00
#     SM Frequency                                                             cycle/usecond                         780.00
#     Elapsed Cycles                                                                   cycle                     33,234,977
#     Memory [%]                                                                           %                          40.86
#     SOL DRAM                                                                             %                           0.98
#     Duration                                                                       msecond                          42.61
#     SOL L1/TEX Cache                                                                     %                          40.87
#     SOL L2 Cache                                                                         %                           0.67
#     SM Active Cycles                                                                 cycle                  33,220,967.07
#     SM [%]                                                                               %                          91.75
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     OK    The kernel is utilizing greater than 80.0% of the available compute or memory performance of the device. To
#           further improve performance, work will likely need to be shifted from the most utilized to another unit.
#           Start by analyzing workloads in the Compute Workload Analysis section.
#
#     Section: Launch Statistics
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     Block Size                                                                                                        256
#     Function Cache Configuration                                                                  cudaFuncCachePreferNone
#     Grid Size                                                                                                      65,536
#     Registers Per Thread                                                   register/thread                             20
#     Shared Memory Configuration Size                                                 Kbyte                          32.77
#     Driver Shared Memory Per Block                                             Kbyte/block                           1.02
#     Dynamic Shared Memory Per Block                                            Kbyte/block                           2.04
#     Static Shared Memory Per Block                                              byte/block                              0
#     Threads                                                                         thread                     16,777,216
#     Waves Per SM                                                                                                   273.07
#     ---------------------------------------------------------------------- --------------- ------------------------------
#
#     Section: Occupancy
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     Block Limit SM                                                                   block                             16
#     Block Limit Registers                                                            block                             10
#     Block Limit Shared Mem                                                           block                             33
#     Block Limit Warps                                                                block                              6
#     Theoretical Active Warps per SM                                                   warp                             48
#     Theoretical Occupancy                                                                %                            100
#     Achieved Occupancy                                                                   %                          99.41
#     Achieved Active Warps Per SM                                                      warp                          47.72
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     OK    This kernel's theoretical occupancy is not impacted by any block limit.
#
#   cudapy::__main__::convolve_kernel$241(Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>), 2021-Jun-20 16:02:34, Context 1, Stream 7
#     Section: GPU Speed Of Light
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     DRAM Frequency                                                           cycle/nsecond                           5.99
#     SM Frequency                                                             cycle/usecond                         779.99
#     Elapsed Cycles                                                                   cycle                     33,235,014
#     Memory [%]                                                                           %                          40.86
#     SOL DRAM                                                                             %                           0.92
#     Duration                                                                       msecond                          42.61
#     SOL L1/TEX Cache                                                                     %                          40.88
#     SOL L2 Cache                                                                         %                           0.63
#     SM Active Cycles                                                                 cycle                  33,220,600.30
#     SM [%]                                                                               %                          91.75
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     OK    The kernel is utilizing greater than 80.0% of the available compute or memory performance of the device. To
#           further improve performance, work will likely need to be shifted from the most utilized to another unit.
#           Start by analyzing workloads in the Compute Workload Analysis section.
#
#     Section: Launch Statistics
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     Block Size                                                                                                        256
#     Function Cache Configuration                                                                  cudaFuncCachePreferNone
#     Grid Size                                                                                                      65,536
#     Registers Per Thread                                                   register/thread                             20
#     Shared Memory Configuration Size                                                 Kbyte                          32.77
#     Driver Shared Memory Per Block                                             Kbyte/block                           1.02
#     Dynamic Shared Memory Per Block                                            Kbyte/block                           2.04
#     Static Shared Memory Per Block                                              byte/block                              0
#     Threads                                                                         thread                     16,777,216
#     Waves Per SM                                                                                                   273.07
#     ---------------------------------------------------------------------- --------------- ------------------------------
#
#     Section: Occupancy
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     Block Limit SM                                                                   block                             16
#     Block Limit Registers                                                            block                             10
#     Block Limit Shared Mem                                                           block                             33
#     Block Limit Warps                                                                block                              6
#     Theoretical Active Warps per SM                                                   warp                             48
#     Theoretical Occupancy                                                                %                            100
#     Achieved Occupancy                                                                   %                          99.41
#     Achieved Active Warps Per SM                                                      warp                          47.72
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     OK    This kernel's theoretical occupancy is not impacted by any block limit.
#
#   cudapy::__main__::convolve_kernel$241(Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>), 2021-Jun-20 16:02:35, Context 1, Stream 7
#     Section: GPU Speed Of Light
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     DRAM Frequency                                                           cycle/nsecond                           6.00
#     SM Frequency                                                             cycle/usecond                         780.01
#     Elapsed Cycles                                                                   cycle                     33,235,373
#     Memory [%]                                                                           %                          40.86
#     SOL DRAM                                                                             %                           0.93
#     Duration                                                                       msecond                          42.61
#     SOL L1/TEX Cache                                                                     %                          40.88
#     SOL L2 Cache                                                                         %                           0.65
#     SM Active Cycles                                                                 cycle                  33,220,825.38
#     SM [%]                                                                               %                          91.75
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     OK    The kernel is utilizing greater than 80.0% of the available compute or memory performance of the device. To
#           further improve performance, work will likely need to be shifted from the most utilized to another unit.
#           Start by analyzing workloads in the Compute Workload Analysis section.
#
#     Section: Launch Statistics
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     Block Size                                                                                                        256
#     Function Cache Configuration                                                                  cudaFuncCachePreferNone
#     Grid Size                                                                                                      65,536
#     Registers Per Thread                                                   register/thread                             20
#     Shared Memory Configuration Size                                                 Kbyte                          32.77
#     Driver Shared Memory Per Block                                             Kbyte/block                           1.02
#     Dynamic Shared Memory Per Block                                            Kbyte/block                           2.04
#     Static Shared Memory Per Block                                              byte/block                              0
#     Threads                                                                         thread                     16,777,216
#     Waves Per SM                                                                                                   273.07
#     ---------------------------------------------------------------------- --------------- ------------------------------
#
#     Section: Occupancy
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     Block Limit SM                                                                   block                             16
#     Block Limit Registers                                                            block                             10
#     Block Limit Shared Mem                                                           block                             33
#     Block Limit Warps                                                                block                              6
#     Theoretical Active Warps per SM                                                   warp                             48
#     Theoretical Occupancy                                                                %                            100
#     Achieved Occupancy                                                                   %                          99.41
#     Achieved Active Warps Per SM                                                      warp                          47.72
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     OK    This kernel's theoretical occupancy is not impacted by any block limit.
#
#   cudapy::__main__::convolve_kernel$241(Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>), 2021-Jun-20 16:02:36, Context 1, Stream 7
#     Section: GPU Speed Of Light
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     DRAM Frequency                                                           cycle/nsecond                           6.00
#     SM Frequency                                                             cycle/usecond                         780.00
#     Elapsed Cycles                                                                   cycle                     33,234,909
#     Memory [%]                                                                           %                          40.86
#     SOL DRAM                                                                             %                           0.92
#     Duration                                                                       msecond                          42.61
#     SOL L1/TEX Cache                                                                     %                          40.87
#     SOL L2 Cache                                                                         %                           0.63
#     SM Active Cycles                                                                 cycle                  33,221,017.73
#     SM [%]                                                                               %                          91.75
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     OK    The kernel is utilizing greater than 80.0% of the available compute or memory performance of the device. To
#           further improve performance, work will likely need to be shifted from the most utilized to another unit.
#           Start by analyzing workloads in the Compute Workload Analysis section.
#
# ...
#     Block Limit SM                                                                   block                             16
#     Block Limit Registers                                                            block                             10
#     Block Limit Shared Mem                                                           block                             33
#     Block Limit Warps                                                                block                              6
#     Theoretical Active Warps per SM                                                   warp                             48
#     Theoretical Occupancy                                                                %                            100
#     Achieved Occupancy                                                                   %                          99.41
#     Achieved Active Warps Per SM                                                      warp                          47.72
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     OK    This kernel's theoretical occupancy is not impacted by any block limit.
#
#   cudapy::__main__::convolve_kernel$241(Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>), 2021-Jun-20 16:02:41, Context 1, Stream 7
#     Section: GPU Speed Of Light
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     DRAM Frequency                                                           cycle/nsecond                           6.00
#     SM Frequency                                                             cycle/usecond                         780.00
#     Elapsed Cycles                                                                   cycle                     33,235,436
#     Memory [%]                                                                           %                          40.86
#     SOL DRAM                                                                             %                           0.95
#     Duration                                                                       msecond                          42.61
#     SOL L1/TEX Cache                                                                     %                          40.87
#     SOL L2 Cache                                                                         %                           0.65
#     SM Active Cycles                                                                 cycle                  33,221,250.50
#     SM [%]                                                                               %                          91.75
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     OK    The kernel is utilizing greater than 80.0% of the available compute or memory performance of the device. To
#           further improve performance, work will likely need to be shifted from the most utilized to another unit.
#           Start by analyzing workloads in the Compute Workload Analysis section.
#
#     Section: Launch Statistics
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     Block Size                                                                                                        256
#     Function Cache Configuration                                                                  cudaFuncCachePreferNone
#     Grid Size                                                                                                      65,536
#     Registers Per Thread                                                   register/thread                             20
#     Shared Memory Configuration Size                                                 Kbyte                          32.77
#     Driver Shared Memory Per Block                                             Kbyte/block                           1.02
#     Dynamic Shared Memory Per Block                                            Kbyte/block                           2.04
#     Static Shared Memory Per Block                                              byte/block                              0
#     Threads                                                                         thread                     16,777,216
#     Waves Per SM                                                                                                   273.07
#     ---------------------------------------------------------------------- --------------- ------------------------------
#
#     Section: Occupancy
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     Block Limit SM                                                                   block                             16
#     Block Limit Registers                                                            block                             10
#     Block Limit Shared Mem                                                           block                             33
#     Block Limit Warps                                                                block                              6
#     Theoretical Active Warps per SM                                                   warp                             48
#     Theoretical Occupancy                                                                %                            100
#     Achieved Occupancy                                                                   %                          99.41
#     Achieved Active Warps Per SM                                                      warp                          47.72
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     OK    This kernel's theoretical occupancy is not impacted by any block limit.
#
#   cudapy::__main__::convolve_kernel$241(Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>), 2021-Jun-20 16:02:42, Context 1, Stream 7
#     Section: GPU Speed Of Light
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     DRAM Frequency                                                           cycle/nsecond                           6.00
#     SM Frequency                                                             cycle/usecond                         780.00
#     Elapsed Cycles                                                                   cycle                     33,234,940
#     Memory [%]                                                                           %                          40.86
#     SOL DRAM                                                                             %                           0.97
#     Duration                                                                       msecond                          42.61
#     SOL L1/TEX Cache                                                                     %                          40.88
#     SOL L2 Cache                                                                         %                           0.66
#     SM Active Cycles                                                                 cycle                  33,220,784.27
#     SM [%]                                                                               %                          91.75
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     OK    The kernel is utilizing greater than 80.0% of the available compute or memory performance of the device. To
#           further improve performance, work will likely need to be shifted from the most utilized to another unit.
#           Start by analyzing workloads in the Compute Workload Analysis section.
#
#     Section: Launch Statistics
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     Block Size                                                                                                        256
#     Function Cache Configuration                                                                  cudaFuncCachePreferNone
#     Grid Size                                                                                                      65,536
#     Registers Per Thread                                                   register/thread                             20
#     Shared Memory Configuration Size                                                 Kbyte                          32.77
#     Driver Shared Memory Per Block                                             Kbyte/block                           1.02
#     Dynamic Shared Memory Per Block                                            Kbyte/block                           2.04
#     Static Shared Memory Per Block                                              byte/block                              0
#     Threads                                                                         thread                     16,777,216
#     Waves Per SM                                                                                                   273.07
#     ---------------------------------------------------------------------- --------------- ------------------------------
#
#     Section: Occupancy
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     Block Limit SM                                                                   block                             16
#     Block Limit Registers                                                            block                             10
#     Block Limit Shared Mem                                                           block                             33
#     Block Limit Warps                                                                block                              6
#     Theoretical Active Warps per SM                                                   warp                             48
#     Theoretical Occupancy                                                                %                            100
#     Achieved Occupancy                                                                   %                          99.41
#     Achieved Active Warps Per SM                                                      warp                          47.72
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     OK    This kernel's theoretical occupancy is not impacted by any block limit.
#
#   cudapy::__main__::convolve_kernel$241(Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>, Array<float, 1, C, mutable, aligned>), 2021-Jun-20 16:02:43, Context 1, Stream 7
#     Section: GPU Speed Of Light
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     DRAM Frequency                                                           cycle/nsecond                           6.00
#     SM Frequency                                                             cycle/usecond                         780.01
#     Elapsed Cycles                                                                   cycle                     33,235,533
#     Memory [%]                                                                           %                          40.86
#     SOL DRAM                                                                             %                           0.98
#     Duration                                                                       msecond                          42.61
#     SOL L1/TEX Cache                                                                     %                          40.88
#     SOL L2 Cache                                                                         %                           0.67
#     SM Active Cycles                                                                 cycle                  33,220,776.90
#     SM [%]                                                                               %                          91.75
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     OK    The kernel is utilizing greater than 80.0% of the available compute or memory performance of the device. To
#           further improve performance, work will likely need to be shifted from the most utilized to another unit.
#           Start by analyzing workloads in the Compute Workload Analysis section.
#
#     Section: Launch Statistics
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     Block Size                                                                                                        256
#     Function Cache Configuration                                                                  cudaFuncCachePreferNone
#     Grid Size                                                                                                      65,536
#     Registers Per Thread                                                   register/thread                             20
#     Shared Memory Configuration Size                                                 Kbyte                          32.77
#     Driver Shared Memory Per Block                                             Kbyte/block                           1.02
#     Dynamic Shared Memory Per Block                                            Kbyte/block                           2.04
#     Static Shared Memory Per Block                                              byte/block                              0
#     Threads                                                                         thread                     16,777,216
#     Waves Per SM                                                                                                   273.07
#     ---------------------------------------------------------------------- --------------- ------------------------------
#
#     Section: Occupancy
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     Block Limit SM                                                                   block                             16
#     Block Limit Registers                                                            block                             10
#     Block Limit Shared Mem                                                           block                             33
#     Block Limit Warps                                                                block                              6
#     Theoretical Active Warps per SM                                                   warp                             48
#     Theoretical Occupancy                                                                %                            100
#     Achieved Occupancy                                                                   %                          99.41
#     Achieved Active Warps Per SM                                                      warp                          47.72
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     OK    This kernel's theoretical occupancy is not impacted by any block limit.
